# %%
# Chemin d'accès au fichier .ipynb dans Google Drive
notebook_api = '/content/drive/MyDrive/Projet_Deep_learning/Api_yaho/api.ipynb'

# %run $notebook_api
# Out:
# ...
# [*********************100%***********************]  1 of 1 completed
# Column 'Volume' has been removed.
# Column 'Adj Close' has been removed.
# Maximum data for EUR/USD saved to eur_usd_max_data.parquet

# %%
# Chemin d'accès au fichier .ipynb dans Google Drive
model_reg_open = '/content/drive/MyDrive/Projet_Deep_learning/notebooks_regression_models/Open.ipynb'

# %run $model_reg_open
# Out:
# Valeur maximale de la colonne: 1.5981844663619995
# Valeur minimale de la colonne: 0.9596191644668579
# [[0.38176077]
#  [0.3703326 ]
#  [0.39053263]
#  ...
#  [0.24122991]
#  [0.22984542]
#  [0.22781581]]
# (4818, 50)
# (4818,)
# (490, 50)
# (490,)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 18s 16ms/step - loss: 0.0109 - mae: 0.0680 - val_loss: 3.4899e-04 - val_mae: 0.0153
# Epoch 2/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 18s 15ms/step - loss: 0.0029 - mae: 0.0405 - val_loss: 1.5381e-04 - val_mae: 0.0100
# Epoch 3/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - loss: 0.0025 - mae: 0.0381 - val_loss: 3.0301e-04 - val_mae: 0.0148
# Epoch 4/100
# ...

# %%
# Chemin d'accès au fichier .ipynb dans Google Drive
model_reg_high = '/content/drive/MyDrive/Projet_Deep_learning/notebooks_regression_models/High.ipynb'

# %run $model_reg_high
# Out:
# Valeur maximale de la colonne: 1.6028209924697876
# Valeur minimale de la colonne: 0.9670057892799377
# [[0.37275158]
#  [0.38359772]
#  [0.38690111]
#  ...
#  [0.23210036]
#  [0.22209549]
#  [0.21756797]]
# (4818, 50)
# (4818,)
# (490, 50)
# (490,)
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 15s 14ms/step - loss: 0.0118 - mae: 0.0686 - val_loss: 6.6253e-04 - val_mae: 0.0220
# Epoch 2/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - loss: 0.0027 - mae: 0.0396 - val_loss: 2.5609e-04 - val_mae: 0.0128
# Epoch 3/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - loss: 0.0021 - mae: 0.0344 - val_loss: 2.1151e-04 - val_mae: 0.0116
# Epoch 4/100
# ...

# %%
# Chemin d'accès au fichier .ipynb dans Google Drive
model_reg_low = '/content/drive/MyDrive/Projet_Deep_learning/notebooks_regression_models/Low.ipynb'

# %run $model_reg_low
# Out:
# Valeur maximale de la colonne: 1.58740234375
# Valeur minimale de la colonne: 0.07290223985910416
# [[0.74050733]
#  [0.74063917]
#  [0.74928891]
#  ...
#  [0.68220978]
#  [0.68042884]
#  [0.68001104]]
# (4818, 50)
# (4818,)
# (490, 50)
# (490,)
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - loss: 0.0225 - mae: 0.0934 - val_loss: 4.7472e-04 - val_mae: 0.0208
# Epoch 2/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - loss: 0.0046 - mae: 0.0521 - val_loss: 2.3729e-04 - val_mae: 0.0138
# Epoch 3/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - loss: 0.0032 - mae: 0.0444 - val_loss: 3.0764e-04 - val_mae: 0.0162
# Epoch 4/100
# ...

# %%
# Chemin d'accès au fichier .ipynb dans Google Drive
model_reg_close = '/content/drive/MyDrive/Projet_Deep_learning/notebooks_regression_models/Close.ipynb'

# %run $model_reg_close
# Out:
# Valeur maximale de la colonne: 1.5987977981567383
# Valeur minimale de la colonne: 0.9596191644668579
# [[0.37060408]
#  [0.38999787]
#  [0.39531734]
#  ...
#  [0.24099844]
#  [0.22962487]
#  [0.22702426]]
# (4818, 50)
# (4818,)
# (490, 50)
# (490,)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 12s 14ms/step - loss: 0.0113 - mae: 0.0692 - val_loss: 7.3951e-04 - val_mae: 0.0241
# Epoch 2/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - loss: 0.0027 - mae: 0.0392 - val_loss: 1.5863e-04 - val_mae: 0.0102
# Epoch 3/100
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - loss: 0.0021 - mae: 0.0345 - val_loss: 0.0012 - val_mae: 0.0331
# Epoch 4/100
# ...

# %%
# Chemin d'accès au fichier .ipynb dans Google Drive
model_action = '/content/drive/MyDrive/Projet_Deep_learning/notebook_model_classification/Action.ipynb'

# %run $model_action
# Out:
# Le nombre : 0
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# <ipython-input-8-875465ce100e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset[i] = 1
# <ipython-input-8-875465ce100e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset[i] = 1
# <ipython-input-8-875465ce100e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset[i] = 1
# ...

# %%
# Chemin d'accès au fichier .ipynb dans Google Drive
prediction = '/content/drive/MyDrive/Projet_Deep_learning/notebook_model_classification/prediction.ipynb'

# %run $prediction
# Out:
# Contenu JSON valide : {'open': 1.1084177891892537, 'High': 1.1106572079545494, 'low': 1.1082363693737958, 'Close': 1.1071760736246539}
# le open est : 1.1084177891892537
# le high est : 1.1106572079545494
# Dernières caractéristiques du nouvel enregistrement:
# diff_open_close           0.001242
# SMA_10                    1.112613
# MACD                      0.001255
# RSI                      48.309441
# price_range               0.002421
# ATR                       0.007332
# Stochastic_Oscillator    23.818486
# Name: 5410, dtype: object
# Modèle et scaler chargés avec succès.
# Prediction for new data: Sell
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:486: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
